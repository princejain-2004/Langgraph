# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI(
    model="deepseek/deepseek-chat",
    base_url="https://openrouter.ai/api/v1",
    api_key=os.getenv("OPENROUTER_API_KEY"),
    temperature=0
)

# %%
class LLMState(TypedDict):
    question: str
    answer: str

# %%
def llm_qa(state: LLMState) -> LLMState:

    #extract the question from state
    question = state['question']
    #form a prompt

    prompt = f'Answer the following question {question}'

    #ask that question to the LLM
    answer = model.invoke(prompt).content
    #upadate the answer in the state

    state['answer'] = answer

    return state

# %%
graph = StateGraph(LLMState)

graph.add_node('llm_qa', llm_qa)

graph.add_edge(START, 'llm_qa')
graph.add_edge('llm_qa', END)

workflow = graph.compile()

# %%
#execute
initial_state = {'question': 'How far is moon from the earth'}

final_state = workflow.invoke(initial_state)

print(final_state['answer'])
# Out:
# The average distance from the Earth to the Moon is approximately **384,400 kilometers (238,855 miles)**. This distance can vary slightly because the Moon follows an elliptical orbit around the Earth, so its distance ranges from about **363,300 kilometers (225,623 miles)** at its closest point (perigee) to **405,500 kilometers (251,966 miles)** at its farthest point (apogee).
