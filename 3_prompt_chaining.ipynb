# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI(
    model="deepseek/deepseek-chat",
    base_url="https://openrouter.ai/api/v1",
    api_key=os.getenv("OPENROUTER_API_KEY"),
    temperature=0
)

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:
    #fetech title

    title = state['title']
    #call llm gen outline

    prompt = f'Generate a outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    #update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:
    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the following outline \n {outline}'


    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
initial_state = {'title' : 'Raise of AI in India'}

final_state = workflow.invoke(initial_state)

print(final_state)
# Out:
# {'title': 'Raise of AI in India', 'outline': '**Title:** The Rise of AI in India: Transforming Industries and Shaping the Future  \n\n**Introduction**  \n- Brief overview of Artificial Intelligence (AI) and its global impact.  \n- India’s growing role in the AI revolution.  \n- Importance of AI in driving innovation, economic growth, and societal transformation.  \n\n**Section 1: India’s AI Ecosystem**  \n- Government initiatives and policies (e.g., National AI Strategy, Digital India).  \n- Role of startups and tech giants in advancing AI adoption.  \n- Investments in AI research and development.  \n\n**Section 2: Key Industries Embracing AI**  \n- Healthcare: AI-powered diagnostics, telemedicine, and drug discovery.  \n- Agriculture: Precision farming, crop monitoring, and yield prediction.  \n- Education: Personalized learning, AI-driven tutoring, and skill development.  \n- Finance: Fraud detection, credit scoring, and robo-advisors.  \n- Manufacturing: Automation, predictive maintenance, and supply chain optimization.  \n\n**Section 3: Challenges and Opportunities**  \n- Challenges: Data privacy, ethical concerns, and skill gaps.  \n- Opportunities: Job creation, global competitiveness, and inclusive growth.  \n- The need for collaboration between government, industry, and academia.  \n\n**Section 4: AI Talent and Innovation in India**  \n- Growth of AI education and training programs.  \n- India’s contribution to global AI research and innovation.  \n- Success stories of Indian AI startups and entrepreneurs.  \n\n**Section 5: The Future of AI in India**  \n- Predictions for AI adoption in the next decade.  \n- Potential impact on India’s GDP and global standing.  \n- The role of AI in addressing societal challenges (e.g., climate change, healthcare access).  \n\n**Conclusion**  \n- Recap of India’s AI journey and its transformative potential.  \n- Call to action for stakeholders to embrace AI responsibly.  \n- Optimistic outlook for India’s AI-driven future.  \n\n**Call-to-Action**  \n- Encourage readers to stay informed about AI developments.  \n- Invite them to share their thoughts on AI’s role in India’s growth.  \n- Suggest resources for learning more about AI.  \n\n**Optional Add-ons**  \n- Infographic: Key statistics on AI adoption in India.  \n- Case Study: Highlight a successful AI implementation in an Indian industry.  \n- Expert Quotes: Insights from Indian AI leaders or researchers.  \n\nThis outline provides a comprehensive structure for a blog that explores the rise of AI in India, its impact on various sectors, and the opportunities and challenges ahead.', 'content': '# **The Rise of AI in India: Transforming Industries and Shaping the Future**  \n\nArtificial Intelligence (AI) is no longer just a futuristic concept—it has become an integral part of our daily lives, reshaping industries, economies, and societies. From virtual assistants to self-driving cars, AI is revolutionizing how we work, learn, and interact. India, with its booming tech industry, vast talent pool, and government-backed initiatives, is emerging as a key player in the global AI revolution.  \n\nWith a thriving startup ecosystem, increasing investments, and AI-driven innovations across healthcare, agriculture, education, and finance, India is poised to become a global AI powerhouse. However, challenges such as data privacy, ethical concerns, and skill gaps must be addressed to harness AI’s full potential.  \n\nIn this blog, we explore India’s AI ecosystem, key industries embracing AI, challenges and opportunities, talent development, and the future of AI in India.  \n\n---\n\n## **Section 1: India’s AI Ecosystem**  \n\nIndia’s AI journey is accelerating rapidly, driven by government policies, private-sector investments, and a growing startup culture.  \n\n### **Government Initiatives & Policies**  \n- **National AI Strategy:** Launched in 2018, the government’s AI roadmap emphasizes research, skill development, and ethical AI deployment.  ...

# %%
print(final_state['outline'])
# Out:
# **Title:** The Rise of AI in India: Transforming Industries and Shaping the Future
#
# **Introduction**
# - Brief overview of Artificial Intelligence (AI) and its global impact.
# - India’s growing role in the AI revolution.
# - Importance of AI in driving innovation, economic growth, and societal transformation.
#
# **Section 1: India’s AI Ecosystem**
# - Government initiatives and policies (e.g., National AI Strategy, Digital India).
# - Role of startups and tech giants in advancing AI adoption.
# - Investments in AI research and development.
#
# **Section 2: Key Industries Embracing AI**
# - Healthcare: AI-powered diagnostics, telemedicine, and drug discovery.
# - Agriculture: Precision farming, crop monitoring, and yield prediction.
# - Education: Personalized learning, AI-driven tutoring, and skill development.
# - Finance: Fraud detection, credit scoring, and robo-advisors.
# - Manufacturing: Automation, predictive maintenance, and supply chain optimization.
#
# **Section 3: Challenges and Opportunities**
# - Challenges: Data privacy, ethical concerns, and skill gaps.
# - Opportunities: Job creation, global competitiveness, and inclusive growth.
# - The need for collaboration between government, industry, and academia.
#
# **Section 4: AI Talent and Innovation in India**
# - Growth of AI education and training programs.
# - India’s contribution to global AI research and innovation.
# - Success stories of Indian AI startups and entrepreneurs.
#
# **Section 5: The Future of AI in India**
# - Predictions for AI adoption in the next decade.
# - Potential impact on India’s GDP and global standing.
# - The role of AI in addressing societal challenges (e.g., climate change, healthcare access).
#
# **Conclusion**
# - Recap of India’s AI journey and its transformative potential.
# - Call to action for stakeholders to embrace AI responsibly.
# - Optimistic outlook for India’s AI-driven future.
#
# **Call-to-Action**
# - Encourage readers to stay informed about AI developments.
# - Invite them to share their thoughts on AI’s role in India’s growth.
# - Suggest resources for learning more about AI.
#
# **Optional Add-ons**
# - Infographic: Key statistics on AI adoption in India.
# - Case Study: Highlight a successful AI implementation in an Indian industry.
# - Expert Quotes: Insights from Indian AI leaders or researchers.
#
# This outline provides a comprehensive structure for a blog that explores the rise of AI in India, its impact on various sectors, and the opportunities and challenges ahead.

# %%
print(final_state['content'])
# Out:
# # **The Rise of AI in India: Transforming Industries and Shaping the Future**
#
# Artificial Intelligence (AI) is no longer just a futuristic concept—it has become an integral part of our daily lives, reshaping industries, economies, and societies. From virtual assistants to self-driving cars, AI is revolutionizing how we work, learn, and interact. India, with its booming tech industry, vast talent pool, and government-backed initiatives, is emerging as a key player in the global AI revolution.
#
# With a thriving startup ecosystem, increasing investments, and AI-driven innovations across healthcare, agriculture, education, and finance, India is poised to become a global AI powerhouse. However, challenges such as data privacy, ethical concerns, and skill gaps must be addressed to harness AI’s full potential.
#
# In this blog, we explore India’s AI ecosystem, key industries embracing AI, challenges and opportunities, talent development, and the future of AI in India.
#
# ---
#
# ## **Section 1: India’s AI Ecosystem**
#
# India’s AI journey is accelerating rapidly, driven by government policies, private-sector investments, and a growing startup culture.
#
# ### **Government Initiatives & Policies**
# - **National AI Strategy:** Launched in 2018, the government’s AI roadmap emphasizes research, skill development, and ethical AI deployment.
# - **Digital India & Make in AI:** Investments in AI infrastructure and localization of AI models for Indian needs.
# - **Public-Private Partnerships:** Collaborations with global tech giants (Microsoft, Google, IBM) to foster AI innovation.
#
# ### **Role of Startups & Tech Giants**
# - AI startups like **SigTuple, Niramai, and Haptik** are making waves in healthcare, fintech, and customer service.
# - Companies like **Tata, Reliance, and Infosys** are integrating AI into cloud computing, automation, and cybersecurity.
# - **Tech hubs** (Bengaluru, Hyderabad, Pune) are becoming AI innovation centers, attracting global investors.
#
# ### **AI Research & Investments**
# - India ranks among the top countries for AI research papers and patents.
# - VC funding in AI startups crossed **$4 billion** in 2023.
# - Institutes like **IITs and IIITs** are launching specialized AI programs.
#
# ---
#
# ## **Section 2: Key Industries Embracing AI**
#
# ### **1. Healthcare – Saving Lives with AI**
# - **AI Diagnostics:** Startups like **Qure.ai** use AI for detecting diseases from X-rays.
# - **Telemedicine:** AI-driven apps provide remote consultations and symptom analysis.
# - **Drug Discovery:** AI models help reduce R&D costs for new medicines.
#
# ### **2. Agriculture – Smart Farming Solutions**
# - **Crop Monitoring:** AI-powered drones analyze soil health and detect pests.
# - **Yield Prediction:** Farmers use AI models to optimize irrigation and fertilizer use.
# - **AI Chatbots:** Tools like **Kisan e-Mitra** assist farmers with real-time advice.
#
# ### **3. Education – Personalized Learning**
# - **AI Tutors:** Platforms like **BYJU’s & Vedantu** offer adaptive learning paths.
# - **Automated Grading:** AI reduces teachers’ workload by assessing assignments.
# - **Skill Development:** AI-powered courses help upskill India’s workforce.
#
# ### **4. Finance – Fraud Detection & Automation**
# - **Fraud Prevention:** Banks use AI to detect suspicious transactions.
# - **Credit Scoring:** Fintechs like **CRED & Razorpay** leverage AI for risk assessment.
# - **Robo-Advisors:** Platforms automate investment strategies for users.
#
# ### **5. Manufacturing – Efficiency & Automation**
# - **Predictive Maintenance:** AI reduces equipment downtime in factories.
# - **Smart Supply Chains:** AI optimizes logistics and inventory management.
# - **AI Robotics:** Automation is transforming India’s manufacturing sector.
#
# ---
#
# ## **Section 3: Challenges & Opportunities**
#
# ### **Challenges**
# - **Data Privacy Concerns:** India’s draft Digital Personal Data Protection Bill aims to regulate AI ethics.
# - **Skill Gap:** Only **5% of engineers** are AI-ready; upskilling is crucial.
# - **Job Disruption:** Automation risks replacing some manual jobs—reskilling is essential.
#
# ### **Opportunities**
# - **Economic Growth:** AI could contribute **$500 billion to India’s GDP by 2025 (McKinsey).**
# - **Job Creation:** AI will generate **millions of new roles** in data science, cybersecurity, and AI ethics.
# - **Global Leadership:** India can become an AI exporter by leveraging its IT talent.
#
# ---
#
# ## **Section 4: AI Talent & Innovation in India**
#
# - **AI Education Boom:** NITI Aayog’s **Responsible AI for Youth** program trains students.
# - **Research Excellence:** IITs and IISc are leading AI research in NLP and robotics.
# - **Startup Success Stories:** Companies like **Zebra Medical Vision (AI imaging) and CropIn (Agri-tech)** show India’s AI potential.
#
# ---
#
# ## **Section 5: The Future of AI in India**
#
# - **By 2030**, AI could revolutionize sectors like climate tech, defense, and smart cities.
# - **GDP Impact:** AI adoption may accelerate India’s growth to a **$10 trillion economy**.
# - **Social Good:** AI can address challenges like pollution, rural healthcare, and education gaps.
#
# ---
#
# ## **Conclusion**
#
# AI is no longer optional—it’s a necessity for India’s progress. With strong government support, corporate investments, and a young, tech-savvy population, India is on track to become an AI superpower. However, balancing innovation with ethics, data security, and inclusive growth will determine how smoothly India transitions into an AI-driven future.
#
# ---
#
# ### **Call to Action**
# What do you think about AI’s role in India’s growth? Share your thoughts in the comments!
#
# Want to learn AI? Check out:
# ✅ **Google AI India**
# ✅ **NPTEL AI Courses**
# ✅ **IIT Madras’ AI certification**
#
# Let’s embrace AI responsibly and shape a smarter, more efficient India! 🚀🤖
#
# ---
#
# *(Optional Add-ons: Infographic, Expert Quotes, Case Study on AI in Indian Healthcare)*
#
# Would you like any modifications or additional sections? Let me know!
